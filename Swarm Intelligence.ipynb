# %% [markdown]
# # Swarm Intelligence Algorithm
#
# List:
# 1. Particle Swarm Optimization (PSO)
# 2. Ant Colony Optimization (ACO)
# 3. Spotted Hyena Optimizer (SHO)
# 4. Artificial Bee Colony (ABC)

# %% [markdown]
# ### Library dan Utilitas

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn

from swarm_intelligence import pso
import utility

# %% [markdown]
# ## Particle Swarm Optimization
# 1. Inisiasi Partikel
# 2. Menghitung fitness score dari setiap partikel
# 3. Menentukan global best
# 4. Apakah partikel apakah sudah sesuai? (ya: (5); tidak (6))
# 5. **Algoritma selesai**
# 6. Menghitung kecepatan
# 7. Perbaharui nilai posisi partikel
# 8. Perbaharui nilai personal best
# 9. Apakah setiap partikel sudah diperbaharui? (ya: (11); tidak (6, partikel lain))
# 10. Perbaharui nilai global best {kembali ke (4)}

# %%
pso = ParticleSwarmOptimization(fit_1, iteration=10)

# %%
pso.execute(show=True)
